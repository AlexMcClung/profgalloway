# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexMcClung/profgalloway/blob/master/uss-university.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('https://github.com/AlexMcClung/profgalloway/raw/master/galloway-data.xlsx')

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(16,10))

sns.scatterplot(x='Value\n(C x E x E)', y='Vulnerability Score', data=df)

plt.show()

# %%
df.columns
# Out:
# Index(['Institution Name', 'Full Time Enrollment', 'State', 'Ranking List',
#        'Rank', 'Rank Pct Rank', 'Undergraduate Admit Rate',
#        'Undergraduate Admit Rate Pct Rank', 'Average Monthly Search Volume',
#        'Average Monthly Search Volume Pct Rank', 'Credential Score',
#        'Student Life Grade', 'Student Life Score', 'Experience Score',
#        '15-Year NPV', '15-Year NPV PCT Rank', '30-Year NPV',
#        '30-Year NPV PCT Rank', 'Instructional Wages per Full-Time Student',
#        'Instructional Wages per Full-Time Student PCT Rank', 'Eduation Score',
#        'Average Undergraduate Tuition', 'Average Undergraduate Tuition Score',
#        'Value\n(C x E x E)', 'Value-to-Cost Ratio',
#        'Endowment per Full Time Student',
#        'Endowment per Full Time Student Pct Rank',
#        'Percentage of International Students',
#        'Percentage of International Students PCT Rank', 'Vulnerability Score',
#        'Prof G Categorization'],
# ...

# %%
df.sample(10)
# Out:
#                           Institution Name  ...  Prof G Categorization
# 128          Hobart William Smith Colleges  ...               Struggle
# 331          University of Hawaii at Manoa  ...                Survive
# 295      The University of Texas at Austin  ...                 Thrive
# 28                         Bowdoin College  ...                 Thrive
# 254                     Simmons University  ...                 Perish
# 377                 University of Richmond  ...                 Thrive
# 112                     Gonzaga University  ...                Survive
# 4                      American University  ...                 Thrive
# 157                    Lipscomb University  ...                 Perish
# 346  University of Massachusetts-Dartmouth  ...                 Perish
#
# [10 rows x 31 columns]
